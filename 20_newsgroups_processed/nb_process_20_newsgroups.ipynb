# %% [markdown]
# # Process 20newsgroups into csv

# %%
import pandas
import os

# %% [markdown]
# ### Create empty dataframe

# %%
dataframe = pandas.DataFrame(columns = ["text", "category", "full_path"])

# %%
dataframe
# Out:
# Empty DataFrame
# Columns: [text, category, full_path]
# Index: []

# %% [markdown]
# ### Process all files in directory, adding contents to dataframe

# %%
partial_path = "/users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/"

# %%
index_counter = 0

for folder in os.listdir(partial_path):
    if folder != ".DS_Store":
        
        #process on the folder level
        folder_path = partial_path + folder + "/"
        
        print("Processing:",folder_path)
        
        for filename in os.listdir(folder_path):
            
            full_path = folder_path + filename
            
            with open(full_path, "r", errors = "ignore") as my_file:
                
                data = my_file.read()
                
            dataframe.loc[index_counter, "text"] = data
            dataframe.loc[index_counter, "category"] = folder
            dataframe.loc[index_counter, "full_path"] = full_path
            
            my_file.close()
                
            index_counter += 1
# Out:
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/talk.politics.mideast/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/rec.autos/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/comp.sys.mac.hardware/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/alt.atheism/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/rec.sport.baseball/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/comp.os.ms-windows.misc/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/rec.sport.hockey/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/sci.crypt/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/sci.med/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/talk.politics.misc/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/rec.motorcycles/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/comp.windows.x/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/comp.graphics/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/comp.sys.ibm.pc.hardware/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/sci.electronics/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/talk.politics.guns/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/sci.space/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/soc.religion.christian/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/misc.forsale/
# Processing: /users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups/talk.religion.misc/

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19997 entries, 0 to 19996
# Data columns (total 3 columns):
# text         19997 non-null object
# category     19997 non-null object
# full_path    19997 non-null object
# dtypes: object(3)
# memory usage: 1.2+ MB

# %% [markdown]
# ### Validate

# %%
dataframe["full_path"].nunique()
# Out:
# 19997

# %%
dataframe["category"].nunique()
# Out:
# 20

# %%
dataframe["text"].nunique()
# Out:
# 19466

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19997 entries, 0 to 19996
# Data columns (total 3 columns):
# text         19997 non-null object
# category     19997 non-null object
# full_path    19997 non-null object
# dtypes: object(3)
# memory usage: 1.2+ MB

# %% [markdown]
# ### Clean strings

# %%
def replace_new_line(string):
    cleaned = string.replace("\n","")
    return cleaned

# %%
dataframe["text_cleaned"] = dataframe["text"].apply(replace_new_line)

# %%
dataframe
# Out:
#                                                     text  \
# 0      Newsgroups: talk.politics.mideast\nPath: canta...
# 1      Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 2      Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 3      Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv....
# 4      Xref: cantaloupe.srv.cs.cmu.edu soc.culture.ar...
# 5      Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...
# 6      Xref: cantaloupe.srv.cs.cmu.edu soc.culture.so...
# 7      Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 8      Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv....
# 9      Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 10     Xref: cantaloupe.srv.cs.cmu.edu soc.culture.tu...
# 11     Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 12     Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv....
# 13     Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 14     Newsgroups: talk.politics.mideast\nPath: canta...
# 15     Newsgroups: talk.politics.mideast\nPath: canta...
# 16     Newsgroups: talk.politics.mideast\nPath: canta...
# 17     Xref: cantaloupe.srv.cs.cmu.edu soc.culture.tu...
# 18     Newsgroups: talk.politics.mideast\nPath: canta...
# 19     Xref: cantaloupe.srv.cs.cmu.edu misc.headlines...
# 20     Xref: cantaloupe.srv.cs.cmu.edu soc.culture.tu...
# 21     Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 22     Xref: cantaloupe.srv.cs.cmu.edu soc.culture.ar...
# 23     Xref: cantaloupe.srv.cs.cmu.edu alt.politics.c...
# 24     Path: cantaloupe.srv.cs.cmu.edu!das-news.harva...
# 25     Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 26     Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 27     Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv....
# 28     Newsgroups: talk.politics.mideast\nPath: canta...
# 29     Xref: cantaloupe.srv.cs.cmu.edu soc.culture.je...
# ...                                                  ...
# 19967  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:53...
# 19968  Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv....
# 19969  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19970  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:54...
# 19971  Path: cantaloupe.srv.cs.cmu.edu!das-news.harva...
# 19972  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:54...
# 19973  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:53...
# 19974  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19975  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
# 19976  Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv....
# 19977  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19978  Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...
# 19979  Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv....
# 19980  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19981  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
# 19982  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
# 19983  Newsgroups: talk.religion.misc\nPath: cantalou...
# 19984  Xref: cantaloupe.srv.cs.cmu.edu alt.pagan:2973...
# 19985  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19986  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
# 19987  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
# 19988  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:53...
# 19989  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
# 19990  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19991  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
# 19992  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19993  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19994  Xref: cantaloupe.srv.cs.cmu.edu sci.skeptic:43...
# 19995  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
# 19996  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
#
#                     category  \
# 0      talk.politics.mideast
# 1      talk.politics.mideast
# 2      talk.politics.mideast
# 3      talk.politics.mideast
# 4      talk.politics.mideast
# 5      talk.politics.mideast
# 6      talk.politics.mideast
# 7      talk.politics.mideast
# 8      talk.politics.mideast
# 9      talk.politics.mideast
# 10     talk.politics.mideast
# 11     talk.politics.mideast
# 12     talk.politics.mideast
# 13     talk.politics.mideast
# 14     talk.politics.mideast
# 15     talk.politics.mideast
# 16     talk.politics.mideast
# 17     talk.politics.mideast
# 18     talk.politics.mideast
# 19     talk.politics.mideast
# 20     talk.politics.mideast
# 21     talk.politics.mideast
# 22     talk.politics.mideast
# 23     talk.politics.mideast
# 24     talk.politics.mideast
# 25     talk.politics.mideast
# 26     talk.politics.mideast
# 27     talk.politics.mideast
# 28     talk.politics.mideast
# 29     talk.politics.mideast
# ...                      ...
# 19967     talk.religion.misc
# 19968     talk.religion.misc
# 19969     talk.religion.misc
# 19970     talk.religion.misc
# 19971     talk.religion.misc
# 19972     talk.religion.misc
# 19973     talk.religion.misc
# 19974     talk.religion.misc
# 19975     talk.religion.misc
# 19976     talk.religion.misc
# 19977     talk.religion.misc
# 19978     talk.religion.misc
# 19979     talk.religion.misc
# 19980     talk.religion.misc
# 19981     talk.religion.misc
# 19982     talk.religion.misc
# 19983     talk.religion.misc
# 19984     talk.religion.misc
# 19985     talk.religion.misc
# 19986     talk.religion.misc
# 19987     talk.religion.misc
# 19988     talk.religion.misc
# 19989     talk.religion.misc
# 19990     talk.religion.misc
# 19991     talk.religion.misc
# 19992     talk.religion.misc
# 19993     talk.religion.misc
# 19994     talk.religion.misc
# 19995     talk.religion.misc
# 19996     talk.religion.misc
#
#                                                full_path  \
# 0      /users/danielcorcoran/desktop/github_repos/pyt...
# 1      /users/danielcorcoran/desktop/github_repos/pyt...
# 2      /users/danielcorcoran/desktop/github_repos/pyt...
# 19989  /users/danielcorcoran/desktop/github_repos/pyt...
# 19990  /users/danielcorcoran/desktop/github_repos/pyt...
# 19991  /users/danielcorcoran/desktop/github_repos/pyt...
# 19992  /users/danielcorcoran/desktop/github_repos/pyt...
# 19993  /users/danielcorcoran/desktop/github_repos/pyt...
# 19994  /users/danielcorcoran/desktop/github_repos/pyt...
# 19995  /users/danielcorcoran/desktop/github_repos/pyt...
# 19996  /users/danielcorcoran/desktop/github_repos/pyt...
#
#                                             text_cleaned
# 0      Newsgroups: talk.politics.mideastPath: cantalo...
# 1      Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 2      Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 3      Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv....
# 4      Xref: cantaloupe.srv.cs.cmu.edu soc.culture.ar...
# 5      Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...
# 6      Xref: cantaloupe.srv.cs.cmu.edu soc.culture.so...
# 7      Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 8      Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv....
# 9      Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 10     Xref: cantaloupe.srv.cs.cmu.edu soc.culture.tu...
# 11     Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 12     Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv....
# 13     Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 14     Newsgroups: talk.politics.mideastPath: cantalo...
# 15     Newsgroups: talk.politics.mideastPath: cantalo...
# 16     Newsgroups: talk.politics.mideastPath: cantalo...
# 17     Xref: cantaloupe.srv.cs.cmu.edu soc.culture.tu...
# 18     Newsgroups: talk.politics.mideastPath: cantalo...
# 19     Xref: cantaloupe.srv.cs.cmu.edu misc.headlines...
# 20     Xref: cantaloupe.srv.cs.cmu.edu soc.culture.tu...
# 21     Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 22     Xref: cantaloupe.srv.cs.cmu.edu soc.culture.ar...
# 23     Xref: cantaloupe.srv.cs.cmu.edu alt.politics.c...
# 24     Path: cantaloupe.srv.cs.cmu.edu!das-news.harva...
# 25     Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 26     Xref: cantaloupe.srv.cs.cmu.edu talk.politics....
# 27     Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv....
# 28     Newsgroups: talk.politics.mideastPath: cantalo...
# 29     Xref: cantaloupe.srv.cs.cmu.edu soc.culture.je...
# ...                                                  ...
# 19967  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:53...
# 19968  Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv....
# 19969  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19970  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:54...
# 19971  Path: cantaloupe.srv.cs.cmu.edu!das-news.harva...
# 19972  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:54...
# 19973  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:53...
# 19974  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19975  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
# 19976  Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv....
# 19977  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19978  Path: cantaloupe.srv.cs.cmu.edu!magnesium.club...
# 19979  Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv....
# 19980  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19981  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
# 19982  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
# 19983  Newsgroups: talk.religion.miscPath: cantaloupe...
# 19984  Xref: cantaloupe.srv.cs.cmu.edu alt.pagan:2973...
# 19985  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19986  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
# 19987  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
# 19988  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:53...
# 19989  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
# 19990  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19991  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
# 19992  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19993  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19994  Xref: cantaloupe.srv.cs.cmu.edu sci.skeptic:43...
# 19995  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
# 19996  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
#
# [19997 rows x 4 columns]

# %% [markdown]
# ### Export

# %%
export_path = "/users/danielcorcoran/desktop/github_repos/python_nb_sklearn_gaussian_naive_bayes/20_newsgroups_processed/20_newsgroups.csv"

dataframe.to_csv(export_path, index_label= "row_index")
